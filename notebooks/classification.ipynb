# %% [markdown]
# ### **Multi-Label Email Classification using BERT Variants for Fine-Tuning**

# %% [markdown]
# #### **1. Set Up**

# %% [markdown]
# #### **2. Data Understanding**

# %% [markdown]
# #### **3. Data Preprocessing**

# %% [markdown]
# #### **4. Model Fine-Tuning**

# %% [markdown]
# #### **5. Model Evaluation**
